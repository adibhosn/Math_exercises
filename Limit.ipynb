# %% [markdown]
# <a href="https://colab.research.google.com/github/adibhosn/Math_exercises/blob/main/Limit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

# %%
x = symbols('x')

# %% [markdown]
# ____________________

# %% [markdown]
# <font size = 5>
#
# Analisando o comportamento da função
#
# </font>

# %%
f = 1 - 1/x
f
# Out:
# 1 - 1/x

# %%
plt = plot(f, (x, -5 , 5), show = False)
plt.ylim = [-10, 10]
plt.show()

# %%
limit(f, x, oo)
# Out:
# 1

# %%
limit(f, x, -oo)
# Out:
# 1

# %% [markdown]
# _________

# %% [markdown]
# <font size = 5>
#
# Determinar o limite
#
# </font>

# %%
f = (2*x - 5)/(x + 8)
f
# Out:
# (2*x - 5)/(x + 8)

# %%
plt = plot(f, (x, -5, 20), show = False)

plt.ylim = [-10, 10]

plt.show()

# %%
limit(f, x, oo)
# Out:
# 2

# %%
plt = plot(f, (x, -9, -200), show = False)

plt.ylim = [-10, 10]

plt.show()

# %%
limit(f, x, -oo)
# Out:
# 2

# %% [markdown]
# ________

# %% [markdown]
# <font size = 5>
#
# Determinar o limite
#
# </font>

# %%
f = (2*x**3 -3*x + 5)/(4*x**5 - 2)
f
# Out:
# (2*x**3 - 3*x + 5)/(4*x**5 - 2)

# %%
plot(f, (x, 2, 20))

# %%
limit(f, x, oo)
# Out:
# 0

# %%
plot(f, (x, 0, -10))

# %%
limit(f, x, -oo)
# Out:
# 0

# %% [markdown]
# ____________

# %% [markdown]
# <font size = 5>
#
# Analisando o comportamento do  função
#
# </font>

# %%
f = 1/(x+1)**2
f
# Out:
# (x + 1)**(-2)

# %%
plt = plot(f, (x,-6, 4), show = False)

plt.ylim = [0, 15]

plt.show()

# %% [markdown]
# __________

# %%
f = 1/x**2

g = 1/x**3

# %%
plt = plot(f, (x, -5, 5), show = False)

plt2 = plot(g, (x, -5, 5), show = False)
plt2[0].line_color = 'r'

plt.append(plt2[0])

plt.ylim = [-10, 10]

plt.show()

# %% [markdown]
# _________

# %% [markdown]
# <font size = 5>
#
# Determinar o limite
#
# </font>

# %%
f = x**3 + sqrt(x) + 1/x**2
f
# Out:
# sqrt(x) + x**3 + x**(-2)

# %%
plt = plot(f, (x, 0, 5), show = False)
plt.ylim = [0, 50]

plt.show()

# %%
limit(f, x, 0, '+')
# Out:
# oo

# %% [markdown]
# _________

# %% [markdown]
# <font size = 5>
#
# Determinar o limite
#
# </font>

# %%
f = 3*x**5 -4*x**3 + 1
f
# Out:
# 3*x**5 - 4*x**3 + 1

# %%
plot(f)

# %%
limit(f, x, oo)
# Out:
# oo

# %%
limit(f, x, -oo)
# Out:
# -oo
